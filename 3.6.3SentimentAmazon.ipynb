# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.mlab import PCA as mlabPCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFECV
from sklearn.svm import SVR
from sklearn.metrics import confusion_matrix

pd.options.display.max_rows = 3000
pd.options.display.max_colwidth = 300


def my_remove_highly_correlated(X,threshold):
    
    #filter out non numbers
    X = X.select_dtypes(include=[np.bool])  #.dropna()
    
    cols = X.columns
 
    #run correlation matrix
    df = X.corr()

    #put df into array
    a = df.values

    #label top half with -99999 
    #we want to ignore top half of matrix
    iu1 = np.triu_indices(len(df))
    a[iu1] = -99999

    #put data back into daraframe
    df = pd.DataFrame(a, columns=cols)
    df['var'] = cols

    #unstack to get a list of var1, var2, correlation
    df = pd.melt(df, id_vars='var')

    #remove those flagged with -99999
    df = df[df.value != -99999].sort_values(by='var', ascending=True)

    #flag remove vs keep based on corr threshold
    df_remove = df[df.value > threshold]
    keep_list = df.loc[df.value <= threshold,'var'].unique()
 
    print('{} out of {} vars removed due to corr greater than {}'.
          format(df_remove.shape[0],X.shape[1],threshold))
    
    print(df_remove)
    print('\nShape before: ' + str(X.shape))
    print('Shape after: ' + str(X[keep_list].shape))
    print('\n')
    return X[keep_list]

def my_confusion_matrix(array_Expected,array_Predicted,colName):
    a = np.array(confusion_matrix(array_Expected, array_Predicted ))
    totalExpectedFalse = a[0,0] + a[0,1]
    totalExpectedTrue = a[1,0] + a[1,1]
    correctFalse = a[0,0] 
    correctTrue = a[1,1] 
    correctTruePct = np.round(correctTrue / totalExpectedTrue,3)
    correctFalsePct = np.round(correctFalse / totalExpectedFalse,3)
    print('Regarding ' + colName + '...')
    print('The model correctly predicted {} Negatives out of {} expected Negatives: {}'.format(
        correctFalse,totalExpectedFalse,correctFalsePct))
    print('The model correctly predicted {} Positives out of {} expected Positives: {}'.format(
        correctTrue,totalExpectedTrue,correctTruePct))    
    print(a)

# %%
file = 'reviews_Toys_and_Games_5.json'
raw_df = pd.read_json(file, lines=True)

print(raw_df.shape)
raw_df.head()
# Out:
# (167597, 9)
#          asin helpful  overall  \
# 0  0439893577  [0, 0]        5
# 1  0439893577  [1, 1]        4
# 2  0439893577  [1, 1]        5
# 3  0439893577  [0, 0]        5
# 4  0439893577  [1, 1]        4
#
#                                                                                                                                                                                                                                                                                                     reviewText  \
# 0                                                                                                                                                                                                         I like the item pricing. My granddaughter wanted to mark on it but I wanted it just for the letters.
# 1                                                                                                                                                                                    Love the magnet easel... great for moving to different areas... Wish it had some sort of non skid pad on bottom though...
# 2  Both sides are magnetic.  A real plus when you're entertaining more than one child.  The four-year old can find the letters for the words, while the two-year old can find the pictures the words spell.  (I bought letters and magnetic pictures to go with this board).  Both grandkids liked it a lot...
# 3                                                                                                                                                        Bought one a few years ago for my daughter and she loves it, still using it today. For the holidays we bought one for our niece and she loved it too.
# 4                                                         I have a stainless steel refrigerator therefore there are not much space for my son to play with his magnet. Brought this for him to put his magnet on. He enjoys sticking his magnet on it. Great to have so he can play with his alphabet magnets.
#
#     reviewTime      reviewerID    reviewerName  \
# 0  01 29, 2014  A1VXOAVRGKGEAK           Angie
# 1  03 28, 2014   A8R62G708TSCM         Candace
# 2  01 28, 2013  A21KH420DK0ICA  capemaychristy
# 3   02 8, 2014   AR29QK6HPFYZ4            dcrm
# 4   05 5, 2014   ACCH8EOML6FN5            DoyZ
#
#                                               summary  unixReviewTime
# 0                                      Magnetic board      1390953600
# 1  it works pretty good for moving to different areas      1395964800
# 2                                          love this!      1359331200
# 3                                   Daughters love it      1391817600
# 4  Great to have so he can play with his alphabet ...      1399248000

# %%
df = raw_df.copy()

#Sample down the data to manageable size
df = df.sample(n=20000)
df.shape
# Out:
# (20000, 9)

# %%
def clean_series(df, col):
        df[col] = df[col].str.lower().str.strip()
        df[col] = df[col].str.replace('.','')
        df[col] = df[col].str.replace(",",'')
        df[col] = df[col].str.replace("!",'')
        df[col] = df[col].str.replace("?",'')
        df[col] = df[col].str.replace(";",'')
        df[col] = df[col].str.replace(":",'')
        df[col] = df[col].str.replace("'",'')
        df[col] = df[col].str.replace("-",'')
        df[col] = df[col].str.replace('"','')
        df[col] = df[col].str.replace('(','') 
        df[col] = df[col].str.replace(')','')
        return df
    

#Set Ratings of 4/5 as Positive
df['Positive'] = np.where(df.overall >= 4, 1, 0)

#Parse all reviews and get counts of each word by Postive vs Negative

#split words for positive reviews and place in list
list_positivewords = []
df.loc[df['Positive'] ==1, 'reviewText'].str.split(' ').apply(list_positivewords.extend)

#Load list into dataframe so that we can get counts in next step
df_positive = pd.DataFrame(list_positivewords, columns=['Words'])
df_positive['Words'] = clean_series(df_positive, 'Words')


#Load counts into new dataframe
array_positive = [df_positive['Words'].value_counts().index.tolist(), df_positive['Words'].value_counts().values.tolist()]  
df_freq_positive = pd.DataFrame(array_positive).transpose()
df_freq_positive.columns = ['Word','Positive_Freq']


list_negativewords = []
df.loc[df['Positive'] ==0, 'reviewText'].str.split(' ').apply(list_negativewords.extend)
df_negative = pd.DataFrame(list_negativewords, columns=['Words'])
df_negative = clean_series(df_negative, 'Words')
array_negative = [df_negative['Words'].value_counts().index.tolist(), df_negative['Words'].value_counts().values.tolist()]  
df_freq_negative = pd.DataFrame(array_negative).transpose()
df_freq_negative.columns = ['Word','Negative_Freq']

merged = pd.merge(df_freq_negative, df_freq_positive, how='outer', left_on='Word', right_on='Word')
print(merged.shape)

#export list to spreadsheet
##merged.to_csv('amazon_pos_neg.csv')
# Out:
# (52236, 3)

# %%
negative_words = ['poor', 'bad','waste','worst','terrible',
                  'dissapo','horrible','broke','junk','didnt',
                  'useless','difficult','return','none','crap',
                  'weak','unreliable','mistake','unfortunate',
                  'nothing','hate','boring','bored','break',
                  'tinny','drain','refund','not good','slow'
                  'dead','fail','worthless','dying','lost',
                  'complain','essentially','unusable', 'no good',
                  'stupid','flimsy','beware','wrong','neither'
                  'forget','lose','warning','joke','bother',
                  '$$$','embarass','flaw','fail','defect','cumbersom',
                  'died','forced','toilet','wobbly','crack',
                  'shouldnt','disap','gimmi','wrong','ugly',
                  'loose','ripped','jerk','mislead','lousy',
                  'excess','stuck','counterf','fake','garbage',
                  'trash','zero','whine','pain','frustr','delay',
                  'unbear','dirty','isnt','disgust','forger',
                  'weird','unsatis','bland','restock','unaccept',
                  'noise','freeze','awkward','too expen','too price',
                  'constant','infuriat','trash','garble','muffle',
                  'suck','unaccept','regret','intermit',
                  'cheap','drawback','sorry','remorse','mess ',
                  'darn', 'damn','crawl','wish',
                  'yell','piti','refuse','fool','inexcus','phony',
                  'phoney','leak', 'unhappy', 'not ',
                  'not recommend', 'be careful', 'died', 'dies', 'barely'
                  'awful','overprice','pointless','shame','shoddy',
                  'mislead','faulty','mediocre','aggravat','return',
                  'dizzy','sick','dud','never','sad','decept','stink'
                 ]

positive_words = ['nice','love','perfect','definit','sturdy',
                 'value','charm','great','super','phenom','wonderf',
                 'outstand','awesom','stell','pleased','comfort',
                 'beaut','fantast','overall','glad',
                 'rocks', 'blast','cute',
                 'excite','amaz','exact','tremend',' slim ','wow',
                 'certain','incred','flawless','surpri',
                 'solid','pleasant','smooth','plenty',
                 'awsom','fabul','prompt','highly',
                 'effective',' mega','#1','best','convenient','sweet',
                 'clever','excel','magic','entertain','enjoy',
                 'exceptional','exceed','winner','hands down',
                 '100%','premium','psyched', 'seamless', 'favorite',
                 'cute','classy','pretty','neat', 'thumbs up',
                 'well', 'good', 'easy', 'on time',
                 'really', 'like', 'peachy', 'compliment', ' plus',
                 'five star', 'a+', '10', 'happy', 'much', 'impress',
                 'must have', 'absolut', 'brilliant', 'easy',
                 'timely', 'cool', 'complete package', 'total package',
                 'holding up', 'very', 'omg', 'fun', 'play'
                 'easy','kids','many','easily','pure','hours']

# %%
#Create a column for each word in our list
#Loop through all of our reviews
#   and label each word as True/False whether that word exists in the review
df2 = df.copy()

for word in negative_words:     
    
    df2[str(word)] = df2['reviewText'].str.contains(word, case=False)


for word in positive_words:    
    
    df2[str(word)] = df2['reviewText'].str.contains(word, case=False)   
    
df2.shape
# Out:
# (20000, 241)

# %%
#split data into X and y

y_train = df2.Positive
X_train = df2.drop(columns=['Positive'], axis=1)
X_train = my_remove_highly_correlated(df2, threshold=.85)
# Out:
# 0 out of 232 vars removed due to corr greater than 0.85
# Empty DataFrame
# Columns: [var, variable, value]
# Index: []
#
# Shape before: (20000, 232)
# Shape after: (20000, 220)

# %%
from sklearn.naive_bayes import BernoulliNB 

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(X_train, y_train)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(X_train)

mislabeled = (y_train != y_pred).sum()
total = X_train.shape[0]

# Display our results.
my_confusion_matrix(y_train, y_pred, 'Toy Reviews')

print("\nNumber of mislabeled points out of a total {} points : {} ({}%)".format(
    total,mislabeled,round(mislabeled/total*100, 2) 
))

#View the mismatches
results = df.copy()
results['y_pred'] = y_pred
results.loc[results.y_pred != results.Positive, ['reviewText','overall','y_pred','Positive']].sort_values('y_pred', ascending=False)
# Out:
# Regarding Toy Reviews...
# The model correctly predicted 1228 Negatives out of 3193 expected Negatives: 0.385
# The model correctly predicted 15862 Positives out of 16807 expected Positives: 0.944
# [[ 1228  1965]
#  [  945 15862]]
#
# Number of mislabeled points out of a total 20000 points : 2910 (14.55%)
#                                                                                                                                                                                                                                                                                                          reviewText  \
# 35504   This game might have more potential if you have a large group, but when playing with a family of 4, it isn't hard to figure out who has which role, there just not a whole lot of suspense or excitement after that.  After only a few times, our game-playing family put this on the shelf.  Maybe if w...
# 2463    The left stick, on the transmitter, controls power and left and right turns. The right hand stick, controls forward/reverse and left/right bank.  This setup is most annoying.  The transmitter antenna is a prop, so don't expect outdoor type range.  This is strictly an indoor toy.The quad copter c...
# 165264  Way too complicated. No game...card, computer, or video game should require you to read the instructions 4 times to get the concept and even than to have someone else read the instructions about 2 more times. This is just to get the concept and the set up of the game. I have even gotten to the p...
# 162661  This is a very fun product, and my daughter - who claims to have a crush on Capt. America - absolutely loves playing with it.  The claim to shoot darts &#34;up to 20 feet away&#34; is probably more accurate on the &#34;up to&#34; part than on the &#34;20 feet&#34; part.  Generally, the darts are...
# 86283   If you read the title, then you already know that I think this gun deserves more that three stars, yet it doesn't merit four. It deserves more than three because it is the first dart tag gun to use a clip and I applaud that since the design of the tagger darts makes that hard to do. However, it'...
# 38459   First let me say, this is one huge, fluffy cat puppet.  We frequently mistake it for one of our real cats at a quick glance.  My daughter LOVES puppets, she is 1 and thinks they are just hilarious.  That being said, this puppet is difficult to use because the opening for your hand is fairly smal...
# 35131   This toy seemed like a great idea for my toddler who really likes scribbling and coloring. It certainly turned bath time into an adventure and my daughter loved it. The crayon star was smaller than I thought it would be but and fits very well into little hands. Unfortunately, at some point my da...
# 150502  This sword is a decent size and durable. I like that the blade is actually a softer plastic and not the hard clunky plastic that the handle is made of. The softer blade means less chance of injury during play, if whacked with it. You can buy Power Cards to insert, which enable more sounds. Not t...
# 60528                                                                                                                                                             This was fun for our daughter for awhile.  She eventually got bored of it, but it did provide some entertainment with a little educational value.
# 94448                                                                                                                                                                                    It's very affordable.  It's cute but not very detailed.  My son was very happy with it.  The quality and thickness was ok.
# 13885                                My 13 month old son received this for his 1st Birthday.He has not played with it since opening it.  The giraffe is absolutely adorable but just sits among his other toys.  He will play with the blocks every once in awhile - but even the blocks do not hold his attention.
# 68705   The gun itself is fantastic.  I need not go into its merits, as I think the ground is covered sufficiently by other reviews on this listing and others for the same gun type.However, this "value" pack is tantamount to a ripoff, when you compare the normal price of the gun.  At prices as of March ...
# 79137   I bought these for my granddaughter but they are very large, much larger than the one she got at a birthday party. We wanted these for fit on a little girl's finger (5-12). These are the size for an adult's fingers. They should give measurements on these. It wasn't a huge loss, but I wanted to t...
# 80335   Greetz,I did like these and so did my daughter but they snap and tear much faster than the LOGO BANDS (if you go into my oyher comments you'll see the Disney Fairies Bands I got as well..and they are much MUCH more durable.I say educational because when kids are trading them for ones they dont h...
# 163147  The Pearl Princess is made of the high quality that you'd expect from a Mattel Barbie doll.  High quality plastics were used and the hair is soft and enticing for you to brush it.The transformation from mermaid to &#34;mermaid princess&#34; was from the mouth of babes, &#34;Lame...&#34;The artic...
# 19044   My twins love to use both sides of the easel. I like that it's adjustable height so it can grow with them. I did not like that the wood used is not treated or protected. Within minutes of using the dry erase markers, they had marks all over the wood pieces framing the top and bottom. They were a...
# 110591  The polly pockets when I grew up were much more sturdy.  They were much more simple with out all the little plastic pieces. I am constantly looking for all the parts to this toy . The accessorie fine. But to allow this piece to work you need all kinds of little pieces and you have to read instru...
# 159518  My family loves to play charades and I thought this would kind of be the same thing but with a twist.Well, it turns out there was a twist but it wasn't for the better.First, the headbands really hurt. They dig into your forehead no matter how you adjust it. After play, we all had red dents in ou...
# 72323   My son plays with these periodically over the past few months, but now that he is one, he is liking the Megablocks better because, as others have noted, they stack much better.  These blocks stack fine so long as you are getting progressively smaller with your layers, but if you try and put a bi...
# 78083                                                                                                                                      I ordered this on recommendation from my adult daughter.  Her children (ages 16, 12 and 10) like this game. So I ordered it to have for my other grandchildren (aged 9).
# 94495                                                                                                                                                                              Cheap.  You get what you pay for!  All the happy birthday tags around the bottles came off.  Some didn't even have a tag at all.
# 148593  I am an IT guy so when I saw this I had to get it to test it out. I always like to see how technology is being implemented in kids toys so they are introduced to it early. As a kid I would have loved something like this toy. Slide the ipad in (make sure the protective screen is on it) and turn i...
# 41943   It looks great in the picture but I have a few gripes- it's top heavy so if my kid, who doesn't know any better yet, pushes too hard on the desk portion when it's folded down or does what kids do- try and climb on it, the entire thing falls forward and there is no way to brace it to a wall to pr...
# 126017  When I saw this on amazon vine, I was anticipating the excitement on my 5-year old twins' faces when this arrived in the mail. They loved this. Extremely easy set up. Download the free app on itunes and one minute later you have yourself a bizarre looking iphone entangled fishing rod. The plasti...
# 99154   Both of my nephews are into anything Star Wars so I thought this mask (they call it a helmet but with only the front being Darth and the back being velcro, it's a mask) would be perfect for them. It fits well on both the adult and child heads. The velcro makes it pretty easy. And for anyone who ...
# 18838   Ok, this is a cute dog, and the premise for it is a good one.  I do have a couple things that annoy me.  You can't touch it without the dog going off, even if it is turned "off".  This becomes a problem if my daughter has gone to sleep with it near and it wakes her up.  And the voice is a bit to...
# 25790                                                                                                            My 2 yo daughter loves pushing this around the yard, but I probably wouldn't buy this again if I could go back - the bubbles don't work (and reading the other reviews, that seems to be a trend).
# 93378                                                  I thought it would be right up his alley but upon opening it and reading the directions, the game is kind of dumb.  I felt like a bad gift giver.  They played it and kind of had to make up their own rules b/c the rules are not very thorough.So skip it.
# 38161   We have several learning resource food sets, and i like them much better than the ones from the local large chain store geared towards all things kids toys.  The learning resource sets tend to have more rubbery thicker toys, and less of the hard plastic molded, or thin plastic cans with taped on...
# 104416  My six year old got a PSP with the HP version for xmas as she loves all the Lego games and plays quite a few; Star Wars, Indiana Jones, etc., Now, granted,I never even noticed this said ages ten and up, just saw the E for everyone, and Ella does tend to play games older than get age as she has a...
# 148306  Bought this figure as a cake topper for my grandson's second birthday who loves the Power Rangers.He ended up eating the figure and we rushed him to the E.R. to get it removed. Finding a parking spot was easy when we got to the E.R. It appeared to me that we would be able to get him taken care o...
# 25340   We had a friend that had these and thought they were awesome. I had to have them. My son loves to build with them. Problems.... you have to put them all together correctly. If you are off on one it makes it hard to stack. They are kind of hard to stack anyway. This can be frusterating to a child...
# 125199                                                                                                                                           It is a fun set, but the cans did not last long and were quickly destroyed by my 2 year old (within 2 months). However he loves the basket so not a complete loss.
# 112644  It's not super interactive, and the kids have to pet it kind of hard to get it to react, but ... they kept going back to play with it, so it's a good toy.Some of the toys we get for our kids get milliseconds of playtime.This little rabbit has drawn them into play on the rug multiple times.So, wh...
# 155737                                                                                                                                                                       The lack of a figure killed the other. If you have to have the Vintage Collection box then buy it - otherwise look for other versions.
# 94061   I'm a LEGO fan (since some months) , who tries to collect all the sets in a Series. And since I have quite a few of the "Pirates of the Caribbean" , I decided to go for this set. And to be frank, I'm not very satisfied with this.I already have a LOT of LEGO sets (and believe me, I'm being modest...
# 103830  I am not crazy about the tambourine.  Having exposed metal for a toddler toy is not a great choice.  The drumsticks are a hazard, too.  That said, the castanets and the maracas are worth it.  She is still playing with them two years later.  The maracas did not have the rings as pictured.  The bu...
# 118517                                                                                        Mad Hatter is very tiny compared to everyone else in this line or any other line he should of been priced at a lower rate . But he is one of 2 Mad hatter figures to come out in the scale of the batman arkham line.
# 51331                                                                                                                                                            Expensive, interesting because it magnified cool things, but after a week it sat unused on the floor for months. I wouldn't recommend buying this.
# 29886   My 6 year old likes this ATM and has fun knowing how much money he has in it.  I searched this type of product online and not many of them had good reviews.  So maybe this is the best there is for a kids' toy.Be warned, however, that it doesn't hold a LOT of money (in coins, anyway.)  The money ...
# 70749                                                 These fairies have a lot of variety and nice detailing, as is typically of Safari LT Toob sets. Unfortunately, we have had trouble with the fairy wings breaking off, but otherwise it is a nice toy - and my daughter still plays with the wingless fairies.
# 101321                                                      this thing is well constructed and works well and as described but my son doesnt really play with it not sure why maybe if it made sounds or had lights or went alittle further or faster when you press the button on his shell he would like it more.
# 74156   My son received this toy when he was 16 months old, so perhaps he was just too old for it. He played with it quite a bit for the first couple of days but then quickly lost interest. It requires no thought or creativity from the child. Since it does the same thing every time, he only puts the car...
# 126749                                                                                                              It is quite fun at the beginning but gets monotonous.the battery runs out quite easily and the singing does not suit the monkey. The sound feels like an adult. Should have used a cuter voice.
# 53782   This product requires every single piece to be clipped from a plastic tree form and then assembled. The fit of assembly was less than perfect as some parts did not quite line up properly. Once assembled, my daughter enjoyed playing with it for a while but quickly grew tired of it as it offers li...
# 164708  Like others have stated the provision of only 1 character (The Finisher) is disappointing - so to enjoy this set properly you'll need to purchase additional characters.  That said the WWE Slam City figures are plenty of fun with their stretchable arms and because they stand about 3 inches tall m...
# 12485   I thought the patterns were wedged/kind of like holes/puzzles that the shapes will sit in. BUT these were on a plain board and my son did not like it. I gave it 3 stars because it is my mistake in not reading other reviews.Amazon must put something in the product description that states this so ...
# 135593  I recently had the opportunity to try the "Pet Frenzied Kids Card Game".  I got it for my granddaughter, thinking it would be good for an upcoming long plane trip. Luckily, we tried it out before the trip. Frankly, it was a bust.  This was way too confusing for the attention span of a 3 year old...
# 61048            Careful folks.  Make sure you buy the one that comes with the AC adapter.  Not sure why it wouldn't be standard with the charger but it chapped my butt that I had to wait another week to use it.  However, it does work great, so I can't complain too much.  A must have for serious RC pilots.
# 126256  It's a fun idea but the execution is lacking.  As most of the other reviewers have noted you spend a lot of time setting it up, cranking away, and you get... some icy soda that isn't anything like a Slurpee.  Maybe there is some amazing technique I'm missing, but I'm not going to learn it.  I ju...
# 121855  When I first saw this product at the toy store I had to have it. After owning it for about a year and a half now I am still on the fence.Cons:~Does not slide well on hard floor surfaces such as laminate or hardwood (the wheels don't turn it just kind of skids in the direction pushed)~The latch t...
# 100097                                                                                                              We own several SmartGames and this one is not my favorite.  It is not as challenging as Camelot Jr or as creative as Trucky3.  My 4 year old played with it only several times since he got it.
# 124343                                                                                                                                                   This pistol is plastic and very easily broken.  My grandson was not very happy about it and I really should have known considering how inexpensive it was.
# 137283  The Rush and Rescue Fire Ladder truck is a good idea with a rather bad design.  The remote is simple to use:  the truck moves only forward or backward, which is easy for a young child to do.  However, the front wheels are not locked in place and the truck wants to turn in big circles.  It is nea...
# 77151   My 3 year old son got this product for his birthday.  The pizza making is a very fun concept, but the dough is impossible. We absolutely love to play with playdoh.  This product cannot compare with playdoh.  Though my son enjoyed playing with it; it is messy and nearly impossible to mold.  It ju...
# 28643   This is a basic keleidoscope. My daughter enjoys looking at it.  We have had it for a year and it is still working.  However, after purchasing this from Amazon I found the exact same kaleidoscope in a retail store for less than half the price that Amazon is asking.  Therefore, I give it 3 stars ...
# 32097                                                                                         It has poor quality sound so its hard to play the game.  If I could do it over, I'd try the diggin wobble deck extreme.  It is made by the same company but is less expensive, more versatile and has better reviews.
# 98598   A simple toy for little boys. The remote has very low range, some one has to chase the car with the remote. Works well when you have small boys... who have lot of energy to burn. The car doesnt flip that well on all surfaces. I wish they had some turn button too and not just forward and reverse....
# 38814                                                                                                                                                                                                The box is very shallow and not easily covered securely. The plastic smell is quite oily and overwhelming too.
# 110614                                                                                                                                    The wheels don't go around on this car. I find that a great drawback. It has a hefty price as well. I did not think it was worth the money. The doors do not open either.
# 90355                                                                                                                                                                                 Havent really start doing thus didnt use this book yet. But this book will come in handy to me since i'm first time doing it!
# 154757  This toy is made of two layers of clear plastic boards that overlap to simulate a 3D image. Comes with 4 neon color markers too enhance the light effects. What you do is just draw on it whatever design you want (time to play with your imagination) and view it while the lights are blinking around...
# 107178  This product set is certainly cheap and I mean both money & quality wise.  I was hopeful that the pieces would be thicker and sturdy. They seem flimsy and I am guessing that the wand may make it a week before snapping. My take is that it would be a great party favor set for a princess themed par...
# 130340  So, this toy comes with three pieces of wood (that's IT?!) a stuffed piggy, 2 stuffed birds, and a mat to place it on.  It's kind of sad that you only get THREE pieces of wood.  Not much you can do with that!  My two year old nephew loved it - but he loves anything Angry Birds.  I wouldn't call ...
# 41621   They're fun, I guess (it's hard for me to think like a 2-year old). They don't float upright. The squirt hole is at the top and the plastic is rather firm, so that feature is not really very useful, especially for small children.  Maybe they're better on dry land. Note that each package might co...
# 161924  cute and very plush and well made, however the pockets aren't very deep for the size.  Meaning, the cat is pretty large and fluffy, but the pockets are very tiny.  You could squish up a tee shirt, or a toddler's pair of pajamas in the large pocket. The mouth can hold something the size of a kid'...
# 61743                                                                                                                                                             All the other Melissa & Doug gardening toys are the right size for a toddler, but these gloves are adult-sized.  Don't get them for your toddler.
# 70344                                                                                                                                                    Just doesn't seem to be Schleich quality.  My girls ages 3 and 6 still think it is cool because they are into fairies and unicorns. Smaller than expected.
# 143680  I was very excited to give this to my almost 2 yr old for Christmas and he seems to like the toy, but it was not the hit that I had anticipated. The arms are quite fragile, my son really wants to hug the toy and take it to bed with him, but you have to be careful with the arms and the toy is qui...
# 39756   I say that because some of the glue is slopped on and some of them dont stick together very well. And it was very stinky out of the package. Over night the smell went away. But my 2 yo loves to play with it. And the piece other than the velcro for some are VERY durable. So all in all not too thr...
# 6399                                                                                                There is not as much strategy as I thought there would be. A lot of rules to learn before playing. Once you've got that all under your belt the play is fairly easy. There is more luck than strategy involved.
# 125821  I was fully prepared to like it but once you stick on the food stickers, hard to remove. I felt like it was a one shot sticker book not for repeat use. Also each table background comes with it's own set of stickers but it's impossible to use all the stickers on that 1 page. So it seems is meant ...
# 104086  This is a rubber doll with a large head, huge eyes, and a very teeny-tiny body. My granddaughter decided she makes a great 'toy' for her larger doll.She has a cute 'rubber' hair style, a little charm and a cardboard guitar. The box says she's for ages 5+. She has a sweet, lovable face. There is ...
# 94817   I gave this to my little three-year-old niece to play with, and I gotta say, it's a strange-looking doll. She kind of gave me a look, like, "Huh?" You squeeze it and it plays a single chord. Together, the bigger doll and the smaller doll it's hugging 'sing' in harmony. Again, I'm not sure how ed...
# 124964                                                                                                                             My 4-year old grandson plays with it, but not in the intended way. The launcher is difficult for him to use, but he enjoys building various configurations for the bird and pig.
# 88883                                            My 4 year old doesn't play with this.  It just sits in the toy box.  She loves strawberry shortcake, but this thing just doesn't do it for her.  It must be durable, it sits in the toy box and takes all the abuse of getting the other toys thrown on top of it.
# 85783   Warning: this bridge is too low.They've designed the red legs a little too short.  You can't make another track go under it cause the trains hit the bridge.This is a pretty fundamental error. What's the point of a bridge if you can't make other tracks go under it?  All of the Fisher Price Take n...
# 29656   Got this toy as a gift and it is cute but really big.  It takes up a lot of room in the toybox and only has about 3 repeat sounds it makes when you push the button.  Wasnt that crazy about it neither was my son.  My infant sometimes plays with it now, she mostly just walks around carrying it by ...
# 118848  This is the kind of product you must carefully tear along the perforated lines to make it look like a spiral.  However, before even doing that, mine was torn in two spots straight out of the packaging.  Tape fixed it but it would have been nice to not have to do that.  I would have given it 5 st...
# 128772                                          Not impressed. The screen is unbelievably tiny and the &#34;mouse&#34; isn't a mouse but just more buttons for navigating. I got this for my son so he wouldn't want to play with my electronics but this has no appeal and the games aren't simple and fun either.
# 95555                                                                                            My 3 year old is a little scared of the mechanical action this toy performs but otherwise likes the toy &#34;from afar&#34;. Hopefully this will change! The extra parts seem to fall off easily (ie Dino's armor)
# 4743                                                                                  This product is just so-so. Makes popping sound but that's about. Won't hold interest for long.Better spend a bit more for one of those poppers with funny heads going up and down when rolled over.A more interesting sight.
# 40439   My 1st child got this as a gift for his 1st birthday.  He LOVED to push the balls through it, but he didn't like it for long when it was turned on.  It is TOO loud. I thought about tossing it quite a few times, but I thought I'd give it another chance with our 2nd child.  The 10 month old baby l...
# ...
# 1387          5       0         1
# 108476        4       0         1
# 42356         5       0         1
# 20066         5       0         1
# 143829        4       0         1
# 155415        4       0         1
# 47897         5       0         1
# 153457        5       0         1
# 89051         5       0         1
# 111687        5       0         1
# 118435        5       0         1
# 82300         5       0         1
# 31093         5       0         1
